# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure

# %%
#drive.mount("/content/drive")

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd "/drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/womens-shoe-prices')

# %%
df = data.dataframes['7003_1']

# %%
df.shape
# Out:
# (19045, 47)

# %%
df.sample(5)
# Out:
#                         id asins         brand  ...          upc websiteids weight
# 9033  AVpfXJjlilAPnD_xaZYG   NaN   New Balance  ...  8.89516E+11        NaN    NaN
# 7290  AVpfXdeM1cnluZ0-jekt   NaN   ELLIE SHOES  ...  8.43266E+11        NaN    NaN
# 5752  AVpfAjkUilAPnD_xS68E   NaN  Ralph Lauren  ...          NaN        NaN    NaN
# 2946  AVpfGuVP1cnluZ0-eAu2   NaN      Columbia  ...          NaN        NaN    NaN
# 6497  AVpfOadjLJeJML435CWg   NaN   Lucky Brand  ...  8.84885E+11        NaN    NaN
#
# [5 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'CAD', 'AUD', 'EUR', nan, 'GBP',
#        'Off Price Direct - Walmart.com', 'new'], dtype=object)

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                               0.956031
# CAD                               0.033515
# AUD                               0.006199
# EUR                               0.003362
# GBP                               0.000788
# Off Price Direct - Walmart.com    0.000053
# new                               0.000053
# Name: prices_currency, dtype: float64

# %%
df_usd = df[ df.prices_currency == 'USD' ].copy()
df_usd.shape
# Out:
# (18199, 47)

# %%
df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
df_usd['prices_amountmin'].hist()

# %%
filter_max = np.percentile( df_usd['prices_amountmin'], 99 )
filter_max
# Out:
# 1100.0

# %%
df_usd_filter = df_usd[ df_usd['prices_amountmin'] < filter_max ]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
df.to_csv('data/w_shoes_prices.csv', index=False)

# %%
# !git add matrix_one/day3.ipynb

# %%
# !git config --global user.email "antykuba@tlen.pl"
# !git config --global user.name "antykuba"

# %%
# !git commit -m "Read Women's Shoe Prices dataset from data.world"
# Out:
# [master b5fc83e] Read Women's Shoe Prices dataset from data.world
#  2 files changed, 2 insertions(+), 129 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 matrix_one/day3.ipynb

# %%
# !git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 19.93 KiB | 2.85 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/antykuba/dw_matrix.git
#    cd36b34..b5fc83e  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
